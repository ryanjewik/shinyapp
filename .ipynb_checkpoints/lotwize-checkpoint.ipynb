# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Ryan Jewik\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\Ryan Jewik\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# %matplotlib inline

# %%
df = pd.read_csv('data\lotwize_case.csv')

# %%
df.shape
# Out:
# (9142, 356)

# %%
df.head()
# Out:
#    schools/0/distance schools/1/grades schools/2/level schools/0/name  \
# 0                 NaN              NaN             NaN            NaN
# 1                 NaN              NaN             NaN            NaN
# 2                 NaN              NaN             NaN            NaN
# 3                 NaN              NaN             NaN            NaN
# 4                 NaN              NaN             NaN            NaN
#
#    schools/1/rating  schools/2/size  schools/0/totalCount schools/1/type  \
# 0               NaN             NaN                   NaN            NaN
# 1               NaN             NaN                   NaN            NaN
# 2               NaN             NaN                   NaN            NaN
# 3               NaN             NaN                   NaN            NaN
# 4               NaN             NaN                   NaN            NaN
#
#   county isRentalListingOffMarket  ...  nearbyHomes/1/propertyTypeDimension  \
# 0    NaN                      NaN  ...                                Condo
# 1    NaN                      NaN  ...                                  NaN
# 2    NaN                      NaN  ...                                  NaN
# 3    NaN                      NaN  ...                                  NaN
# 4    NaN                      NaN  ...                                  NaN
#
#   nearbyHomes/1/state  nearbyHomes/2/bathrooms  nearbyHomes/2/bedrooms  \
# 0                  CA                      2.0                     2.0
# 1                 NaN                      NaN                     NaN
# 2                 NaN                      NaN                     NaN
# 3                 NaN                      NaN                     NaN
# 4                 NaN                      NaN                     NaN
#
#    nearbyHomes/2/livingArea nearbyHomes/2/livingAreaUnits  \
# 0                    1555.0                   Square Feet
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#   nearbyHomes/2/livingAreaUnitsShort nearbyHomes/2/livingAreaValue  \
# 0                               sqft                        1555.0
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#   nearbyHomes/2/zpid resoFacts/flooring/0
# 0        111718685.0                 Tile
# 1                NaN                 Tile
# 2                NaN             Hardwood
# 3                NaN                  NaN
# 4                NaN                  NaN
#
# [5 rows x 356 columns]

# %%
df['price'] #what we are predicting?
# Out:
# 0       1500000
# 1       1675000
# 2       2400000
# 3       1475000
# 4       1170000
#          ...
# 9137     690000
# 9138     700000
# 9139     785000
# 9140     709000
# 9141     707000
# Name: price, Length: 9142, dtype: int64

# %%
sns.heatmap(df.corr(numeric_only=True), annot = False)
# Out:
# <Axes: >

# %%
predictors = df.columns.tolist()

# %%
df['monthlyHoaFee'].value_counts()
# Out:
# monthlyHoaFee
# 300.0     44
# 360.0     32
# 390.0     32
# 450.0     31
# 150.0     31
#           ..
# 1093.0     1
# 1086.0     1
# 1055.0     1
# 876.0      1
# 790.0      1
# Name: count, Length: 696, dtype: int64

# %%
predictors
# Out:
# ['schools/0/distance',
#  'schools/1/grades',
#  'schools/2/level',
#  'schools/0/name',
#  'schools/1/rating',
#  'schools/2/size',
#  'schools/0/totalCount',
#  'schools/1/type',
#  'county',
#  'isRentalListingOffMarket',
#  'mortgageRates/thirtyYearFixedRate',
#  'propertyTypeDimension',
#  'monthlyHoaFee',
#  'nearbyHomes/3/latitude',
#  'nearbyHomes/3/longitude',
#  'resoFacts/constructionMaterials/0',
#  'resoFacts/flooring/1',
#  'resoFacts/rooms/1/roomFeatures/0',
#  'resoFacts/propertyCondition',
#  'resoFacts/foundationDetails/0',
#  'resoFacts/architecturalStyle',
#  'resoFacts/fencing',
#  'resoFacts/utilities/0',
#  'resoFacts/view/0',
#  'resoFacts/rooms/1/roomType',
#  'resoFacts/storiesTotal',
#  'resoFacts/interiorFeatures/0',
#  'resoFacts/listingTerms',
#  'resoFacts/communityFeatures/0',
#  'resoFacts/fireplaces',
#  'resoFacts/patioAndPorchFeatures/0',
#  'resoFacts/patioAndPorchFeatures/1',
#  'resoFacts/patioAndPorchFeatures/2',
#  'nearbyHomes/0/homeStatus',
#  'nearbyHomes/1/lotAreaValue',
#  'nearbyHomes/2/price',
#  'nearbyHomes/3/homeType',
#  'priceHistory/0/price',
#  'priceHistory/1/date',
#  'priceHistory/2/price',
#  'priceHistory/3/date',
#  'priceHistory/4/price',
#  'priceHistory/5/date',
#  'adTargets/aamgnrc1',
#  'adTargets/bd',
#  'adTargets/city',
#  'adTargets/listtp',
#  'adTargets/lot',
#  'adTargets/mlat',
#  'adTargets/mlong',
#  'adTargets/prange',
#  'adTargets/price',
#  'adTargets/price_band',
#  'adTargets/proptp',
#  'adTargets/sqft',
#  'adTargets/sqftrange',
#  'adTargets/state',
#  'adTargets/yrblt',
#  'adTargets/zestibuck',
#  'adTargets/zip',
#  'address/city',
#  'address/streetAddress',
#  'address/zipcode',
#  'attributionInfo/lastChecked',
#  'attributionInfo/lastUpdated',
#  'attributionInfo/listingAgents/0/associatedAgentType',
#  'attributionInfo/listingAgents/1/associatedAgentType',
#  'attributionInfo/listingOffices/0/officeName',
#  'attributionInfo/listingOffices/1/associatedOfficeType',
#  'attributionInfo/mlsId',
#  'bathrooms',
#  'bedrooms',
#  'city',
#  'cityId',
#  'countyFIPS',
#  'countyId',
#  'currency',
#  'dateSoldString',
#  'description',
#  'formattedChip/location/0/fullValue',
#  'formattedChip/location/1/fullValue',
#  'hasBadGeocode',
#  'hasPublicVideo',
#  'hdpUrl',
#  'homeStatus',
#  'homeType',
#  'isCurrentSignedInAgentResponsible',
#  'isCurrentSignedInUserVerifiedOwner',
#  'isHousingConnector',
#  'isListingClaimedByCurrentSignedInUser',
#  'isNonOwnerOccupied',
#  'isPremierBuilder',
#  'lastSoldPrice',
#  'latitude',
#  'listedBy/0/elements/0/id',
#  'listedBy/0/elements/0/text',
#  'listedBy/0/elements/1/id',
#  'listedBy/0/elements/1/text',
#  'listedBy/0/elements/2/id',
#  'listedBy/0/elements/2/text',
#  'listedBy/0/id',
#  'listedBy/1/elements/0/id',
#  'listedBy/1/elements/0/text',
#  'listedBy/1/id',
#  'listingDataSource',
#  'livingArea',
#  'livingAreaUnits',
#  'livingAreaUnitsShort',
#  'livingAreaValue',
#  'longitude',
#  'lotAreaUnits',
#  'lotAreaValue',
#  'lotSize',
#  'maloneId',
#  'mortgageZHLRates/thirtyYearFixedBucket/lastUpdated',
#  'mortgageZHLRates/thirtyYearFixedBucket/rate',
#  'mortgageZHLRates/thirtyYearFixedBucket/rateSource',
#  'nearbyHomes/0/address/city',
#  'nearbyHomes/0/address/state',
#  'nearbyHomes/0/address/streetAddress',
#  'nearbyHomes/0/address/zipcode',
#  'nearbyHomes/0/bathrooms',
#  'nearbyHomes/0/bedrooms',
#  'nearbyHomes/0/formattedChip/location/0/fullValue',
#  'nearbyHomes/0/hdpTypeDimension',
#  'nearbyHomes/0/homeType',
#  'nearbyHomes/0/isPremierBuilder',
#  'nearbyHomes/0/isShowcaseListing',
#  'nearbyHomes/0/latitude',
#  'nearbyHomes/0/listingMetadata/comminglingCategoryIsRulesApplicable',
#  'nearbyHomes/0/listingTypeDimension',
#  'nearbyHomes/0/livingArea',
#  'nearbyHomes/0/livingAreaUnits',
#  'nearbyHomes/0/livingAreaUnitsShort',
#  'nearbyHomes/0/livingAreaValue',
#  'nearbyHomes/0/longitude',
#  'nearbyHomes/0/lotAreaUnits',
#  'nearbyHomes/0/lotAreaValue',
#  'nearbyHomes/0/lotSize',
#  'nearbyHomes/0/price',
#  'nearbyHomes/0/propertyTypeDimension',
#  'nearbyHomes/0/state',
#  'nearbyHomes/0/zpid',
#  'nearbyHomes/1/bathrooms',
#  'nearbyHomes/1/bedrooms',
#  'nearbyHomes/1/livingArea',
#  'nearbyHomes/1/livingAreaUnits',
#  'nearbyHomes/1/livingAreaUnitsShort',
#  'nearbyHomes/1/livingAreaValue',
#  'nearbyHomes/1/price',
#  'nearbyHomes/1/zpid',
#  'neighborhoodMapThumb/0/url',
#  'parcelId',
#  'parentRegion/name',
#  'photoCount',
#  'postingContact/name',
#  'price',
#  'priceHistory/0/attributeSource/infoString1',
#  'priceHistory/0/attributeSource/infoString2',
#  'priceHistory/0/attributeSource/infoString3',
#  'priceHistory/0/date',
#  'priceHistory/0/event',
#  'priceHistory/0/postingIsRental',
#  'priceHistory/0/priceChangeRate',
#  'priceHistory/0/pricePerSquareFoot',
#  'priceHistory/0/showCountyLink',
#  'priceHistory/0/source',
#  'priceHistory/0/time',
#  'priceHistory/1/attributeSource/infoString1',
#  'priceHistory/1/attributeSource/infoString2',
#  'priceHistory/1/attributeSource/infoString3',
#  'priceHistory/1/event',
#  'priceHistory/1/postingIsRental',
#  'priceHistory/1/price',
#  'priceHistory/1/priceChangeRate',
#  'priceHistory/1/pricePerSquareFoot',
#  'priceHistory/1/showCountyLink',
#  'priceHistory/1/source',
#  'priceHistory/1/time',
#  'priceHistory/2/attributeSource/infoString2',
#  'priceHistory/2/date',
#  'priceHistory/2/event',
#  'priceHistory/2/postingIsRental',
#  'priceHistory/2/priceChangeRate',
#  'priceHistory/2/pricePerSquareFoot',
#  'priceHistory/2/showCountyLink',
#  'priceHistory/2/source',
#  'priceHistory/2/time',
#  'propertyTaxRate',
#  'rentZestimate',
#  'resoFacts/appliances/0',
#  'resoFacts/atAGlanceFacts/0/factLabel',
#  'resoFacts/atAGlanceFacts/0/factValue',
#  'resoFacts/atAGlanceFacts/1/factLabel',
#  'resoFacts/atAGlanceFacts/1/factValue',
#  'resoFacts/atAGlanceFacts/2/factLabel',
#  'resoFacts/atAGlanceFacts/2/factValue',
#  'resoFacts/atAGlanceFacts/3/factLabel',
#  'resoFacts/atAGlanceFacts/3/factValue',
#  'resoFacts/atAGlanceFacts/4/factLabel',
#  'resoFacts/atAGlanceFacts/4/factValue',
#  'resoFacts/atAGlanceFacts/5/factLabel',
#  'resoFacts/atAGlanceFacts/5/factValue',
#  'resoFacts/atAGlanceFacts/6/factLabel',
#  'resoFacts/bathrooms',
#  'resoFacts/bathroomsFloat',
#  'resoFacts/bathroomsFull',
#  'resoFacts/bathroomsHalf',
#  'resoFacts/bedrooms',
#  'resoFacts/buildingArea',
#  'resoFacts/canRaiseHorses',
#  'resoFacts/cityRegion',
#  'resoFacts/cooling/0',
#  'resoFacts/coveredParkingCapacity',
#  'resoFacts/feesAndDues/0/type',
#  'resoFacts/fireplaceFeatures/0',
#  'resoFacts/furnished',
#  'resoFacts/garageParkingCapacity',
#  'resoFacts/hasAdditionalParcels',
#  'resoFacts/hasAssociation',
#  'resoFacts/hasAttachedGarage',
#  'resoFacts/hasAttachedProperty',
#  'resoFacts/hasCarport',
#  'resoFacts/hasCooling',
#  'resoFacts/hasFireplace',
#  'resoFacts/hasGarage',
#  'resoFacts/hasHeating',
#  'resoFacts/hasHomeWarranty',
#  'resoFacts/hasLandLease',
#  'resoFacts/hasSpa',
#  'resoFacts/hasView',
#  'resoFacts/heating/0',
#  'resoFacts/highSchoolDistrict',
#  'resoFacts/homeType',
#  'resoFacts/isNewConstruction',
#  'resoFacts/laundryFeatures/0',
#  'resoFacts/levels',
#  'resoFacts/listAOR',
#  'resoFacts/livingArea',
#  'resoFacts/lotFeatures/0',
#  'resoFacts/lotSize',
#  'resoFacts/onMarketDate',
#  'resoFacts/parcelNumber',
#  'resoFacts/parkingCapacity',
#  'resoFacts/parkingFeatures/0',
#  'resoFacts/poolFeatures/0',
#  'resoFacts/pricePerSquareFoot',
#  'resoFacts/propertySubType/0',
#  'resoFacts/roofType',
#  'resoFacts/rooms/0/roomType',
#  'resoFacts/sewer/0',
#  'resoFacts/specialListingConditions',
#  'resoFacts/stories',
#  'resoFacts/waterSource/0',
#  'resoFacts/yearBuilt',
#  'resoFacts/zoning',
#  'restimateHighPercent',
#  'restimateLowPercent',
#  'restimateMinus30',
#  'ssid',
#  'state',
#  'stateId',
#  'staticMap/sources/0/url',
#  'staticMap/sources/1/url',
#  'staticMap/sources/3/url',
#  'staticMap/sources/4/url',
#  'streetAddress',
#  'streetView/addressSources/0/url',
#  'streetView/addressSources/1/url',
#  'streetView/addressSources/2/url',
#  'streetView/latLongSources/0/url',
#  'streetView/latLongSources/2/url',
#  'streetViewTileImageUrlMediumAddress',
#  'streetViewTileImageUrlMediumLatLong',
#  'taxAssessedValue',
#  'taxAssessedYear',
#  'taxHistory/0/taxIncreaseRate',
#  'taxHistory/0/time',
#  'taxHistory/0/value',
#  'taxHistory/0/valueIncreaseRate',
#  'taxHistory/1/taxIncreaseRate',
#  'taxHistory/1/taxPaid',
#  'taxHistory/1/time',
#  'taxHistory/1/value',
#  'taxHistory/1/valueIncreaseRate',
#  'taxHistory/2/taxIncreaseRate',
#  'taxHistory/2/taxPaid',
#  'taxHistory/2/time',
#  'taxHistory/2/value',
#  'taxHistory/2/valueIncreaseRate',
#  'taxHistory/3/taxIncreaseRate',
#  'taxHistory/3/taxPaid',
#  'taxHistory/3/time',
#  'taxHistory/3/value',
#  'taxHistory/3/valueIncreaseRate',
#  'taxHistory/4/taxIncreaseRate',
#  'taxHistory/4/taxPaid',
#  'taxHistory/4/time',
#  'taxHistory/4/value',
#  'taxHistory/4/valueIncreaseRate',
#  'taxHistory/5/taxIncreaseRate',
#  'taxHistory/5/taxPaid',
#  'taxHistory/5/time',
#  'taxHistory/5/value',
#  'taxHistory/5/valueIncreaseRate',
#  'taxHistory/6/taxIncreaseRate',
#  'taxHistory/6/time',
#  'taxHistory/6/value',
#  'taxHistory/6/valueIncreaseRate',
#  'taxHistory/7/taxIncreaseRate',
#  'taxHistory/7/taxPaid',
#  'taxHistory/7/value',
#  'taxHistory/7/valueIncreaseRate',
#  'taxHistory/8/taxIncreaseRate',
#  'taxHistory/8/taxPaid',
#  'taxHistory/8/time',
#  'taxHistory/8/valueIncreaseRate',
#  'taxHistory/9/taxIncreaseRate',
#  'taxHistory/9/taxPaid',
#  'taxHistory/9/time',
#  'taxHistory/9/value',
#  'thumb/0/url',
#  'tourViewCount',
#  'yearBuilt',
#  'zestimate',
#  'zestimateHighPercent',
#  'zestimateLowPercent',
#  'zestimateMinus30',
#  'zipcode',
#  'zpid',
#  'nearbyHomes/1/address/city',
#  'nearbyHomes/1/address/state',
#  'nearbyHomes/1/address/streetAddress',
#  'nearbyHomes/1/address/zipcode',
#  'nearbyHomes/1/formattedChip/location/0/fullValue',
#  'nearbyHomes/1/hdpTypeDimension',
#  'nearbyHomes/1/homeStatus',
#  'nearbyHomes/1/homeType',
#  'nearbyHomes/1/isPremierBuilder',
#  'nearbyHomes/1/isShowcaseListing',
#  'nearbyHomes/1/latitude',
#  'nearbyHomes/1/listingMetadata/comminglingCategoryIsRulesApplicable',
#  'nearbyHomes/1/listingTypeDimension',
#  'nearbyHomes/1/longitude',
#  'nearbyHomes/1/lotAreaUnits',
#  'nearbyHomes/1/lotSize',
#  'nearbyHomes/1/propertyTypeDimension',
#  'nearbyHomes/1/state',
#  'nearbyHomes/2/bathrooms',
#  'nearbyHomes/2/bedrooms',
#  'nearbyHomes/2/livingArea',
#  'nearbyHomes/2/livingAreaUnits',
#  'nearbyHomes/2/livingAreaUnitsShort',
#  'nearbyHomes/2/livingAreaValue',
#  'nearbyHomes/2/zpid',
#  'resoFacts/flooring/0']

# %%
predictors.remove('zestimate')

# %%
corr_matrix = df.corr(numeric_only=True)

# Extract the correlations with 'zestimate'
zestimate_corr = corr_matrix[['price']].drop('price')
# Filter out correlations between 0.5 and -0.5
filtered_corr = zestimate_corr[(zestimate_corr['price'] >= 0.5) | (zestimate_corr['price'] <= -0.5)]

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(filtered_corr, annot=False, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation between Predictors and Price')
plt.show()
#looking at coorelation between predictors and price, only variables outside of 0.5 and -.5 coorelation

# %%
# Get the list of variables to keep
variables_to_keep = filtered_corr.index.tolist()

# Add 'zestimate' to the list of variables to keep
variables_to_keep.append('price')

# Filter the DataFrame to keep only the relevant variables
filtered_df = df[variables_to_keep]

# Display the filtered DataFrame
print(filtered_df.head())
#this filtered dataframe only has variables outside of 0.5 to -0.5 coorelation
# Out:
#    schools/1/rating  mortgageRates/thirtyYearFixedRate  \
# 0               NaN                                NaN
# 1               NaN                                NaN
# 2               NaN                                NaN
# 3               NaN                                NaN
# 4               NaN                                NaN
#
#    nearbyHomes/3/latitude  nearbyHomes/3/longitude  nearbyHomes/2/price  \
# 0                     NaN                      NaN            1144900.0
# 1                     NaN                      NaN                  NaN
# 2                     NaN                      NaN                  NaN
# 3                     NaN                      NaN                  NaN
# 4                     NaN                      NaN                  NaN
#
#    priceHistory/0/price  priceHistory/2/price  priceHistory/4/price  \
# 0             1500000.0             1299000.0                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    adTargets/mlat  adTargets/price  ...  taxHistory/5/value  \
# 0             NaN        1500000.0  ...            867856.0
# 1             NaN              NaN  ...                 NaN
# 2             NaN              NaN  ...                 NaN
# 3        33.82656        1475000.0  ...            429579.0
# 4             NaN              NaN  ...                 NaN
#
#    taxHistory/6/value  taxHistory/7/taxPaid  taxHistory/7/value  \
# 0            850840.0              10303.58            834148.0
# 1                 NaN                   NaN                 NaN
# 2                 NaN                   NaN                 NaN
# 3            421156.0               4630.56            412899.0
# 4                 NaN                   NaN                 NaN
#
#    taxHistory/8/taxPaid  taxHistory/9/taxPaid  taxHistory/9/value  zestimate  \
# 0              10128.48              10004.28            805512.0  1494700.0
# 1                   NaN                   NaN                 NaN  1675000.0
# 2                   NaN                   NaN                 NaN  2380400.0
# 3               4540.64               4376.78            398731.0  1468700.0
# 4                   NaN                   NaN                 NaN  1170700.0
#
#    zestimateMinus30    price
# 0         1420732.0  1500000
# 1               NaN  1675000
# 2               NaN  2400000
# 3         1483733.0  1475000
# 4               NaN  1170000
#
# [5 rows x 39 columns]

# %%
filtered_df.columns
# Out:
# Index(['schools/1/rating', 'mortgageRates/thirtyYearFixedRate',
#        'nearbyHomes/3/latitude', 'nearbyHomes/3/longitude',
#        'nearbyHomes/2/price', 'priceHistory/0/price', 'priceHistory/2/price',
#        'priceHistory/4/price', 'adTargets/mlat', 'adTargets/price',
#        'countyFIPS', 'lastSoldPrice',
#        'mortgageZHLRates/thirtyYearFixedBucket/rate', 'nearbyHomes/0/price',
#        'nearbyHomes/1/price', 'priceHistory/1/price', 'rentZestimate',
#        'resoFacts/bathroomsFull', 'taxAssessedValue', 'taxHistory/0/value',
#        'taxHistory/1/taxPaid', 'taxHistory/1/value', 'taxHistory/2/taxPaid',
#        'taxHistory/2/value', 'taxHistory/3/taxPaid', 'taxHistory/3/value',
#        'taxHistory/4/taxPaid', 'taxHistory/4/value', 'taxHistory/5/taxPaid',
#        'taxHistory/5/value', 'taxHistory/6/value', 'taxHistory/7/taxPaid',
#        'taxHistory/7/value', 'taxHistory/8/taxPaid', 'taxHistory/9/taxPaid',
#        'taxHistory/9/value', 'zestimate', 'zestimateMinus30', 'price'],
#       dtype='object')

# %%
filtered_df.shape
# Out:
# (9142, 39)

# %%
# Remove rows with any null values
filtered_df = filtered_df.dropna()

# %%
filtered_df.shape
# Out:
# (46, 39)

# %%
filtered_df
# Out:
#       schools/1/rating  mortgageRates/thirtyYearFixedRate  \
# 3299               4.0                              6.194
# 3741               5.0                              5.527
# 3747               7.0                              5.527
# 3761               8.0                              5.527
# 3788               2.0                              5.527
# 8753               36.795444              -119.677780             499500.0
# 8949               36.861153              -119.740040                  0.0
#
#       priceHistory/0/price  priceHistory/2/price  priceHistory/4/price  \
# 3299             2300000.0             1795000.0             1795000.0
# 3741              295000.0              307500.0              315000.0
# 3747              392000.0              385000.0              350000.0
# 3761              469000.0              459000.0              257200.0
# 3788              290000.0                1487.0                1495.0
# 3834              335000.0              329000.0              329000.0
# 3835              410000.0              419900.0              430000.0
# 3847              311000.0              288900.0              288900.0
# 3855              370000.0              375000.0              385000.0
# 3872              324000.0                1650.0              225000.0
# 4881              422000.0              432000.0              432000.0
# 4911              385000.0              399500.0              230000.0
# 4913              280000.0              349000.0               78702.0
# 4915              360000.0              364999.0              348000.0
# 4916              262000.0              275000.0              103000.0
# 4961              380000.0              380000.0              380000.0
# 4964              295000.0              174900.0              230000.0
# 4967              445000.0              427500.0              269000.0
# 5317              325000.0              328767.0              215000.0
# 5322              270000.0              310000.0              310000.0
# 5345              270000.0              269900.0               65000.0
# 5403              392500.0              244500.0               96500.0
# 5408              200000.0              134950.0                1050.0
# 5422              365000.0              309950.0              329950.0
# 5431              200000.0               80000.0               89000.0
# 5432              220000.0              239000.0              259000.0
# 5437              421000.0              275000.0              275000.0
# 5479              299900.0              299900.0              319900.0
# 5500              242500.0              245000.0              230000.0
# 5534              400000.0                1650.0              230000.0
# 5536              499000.0              499000.0              499000.0
# 5565              355000.0              350000.0              350000.0
# 5606              429000.0              429000.0              259500.0
# 5607              375000.0              415000.0              121053.0
# 5623              415000.0              435900.0              272000.0
# 5641              313200.0              315000.0              118500.0
# 5658              304000.0              299000.0              299000.0
# 5675              405000.0              390000.0              390000.0
# 5686              335000.0              329000.0              324000.0
# 5695              320000.0              324500.0              106000.0
# 5745              380000.0              414000.0              100000.0
# 6515              800000.0              320000.0              390000.0
# 6529              865000.0              857000.0              910000.0
# 7709              640000.0              660000.0              275000.0
# 8753              683000.0              688000.0              591000.0
# 8949              697000.0                2300.0              360000.0
#
#       adTargets/mlat  adTargets/price  ...  taxHistory/5/value  \
# 3299       36.846410        2300000.0  ...           1632000.0
# 3741       36.702220         295000.0  ...             69446.0
# 3747       36.828830         392000.0  ...            126329.0
# 3761       36.843994         469000.0  ...            274868.0
# 3788       36.781900         290000.0  ...            106742.0
# 3834       36.811530         335000.0  ...            229452.0
# 3835       36.811188         410000.0  ...            238771.0
# 3847       37.198840         311000.0  ...            290598.0
# 3855       36.802470         370000.0  ...            120338.0
# 3872       36.767925         324000.0  ...            294500.0
# 4881       36.805660         422000.0  ...            280700.0
# 4911       36.824700         385000.0  ...             77682.0
# 4913       36.804390         280000.0  ...            128751.0
# 4915       36.819103         360000.0  ...             34072.0
# 4916       36.818590         262000.0  ...            113698.0
# 4961       36.704590         380000.0  ...             23139.0
# 4964       36.788020         295000.0  ...            196709.0
# 4967       36.702663         445000.0  ...            274000.0
# 5317       36.804623         325000.0  ...             68663.0
# 5322       36.804634         270000.0  ...             59177.0
# 5345       36.768887         270000.0  ...             71566.0
# 5403       36.775430         392500.0  ...            252565.0
# 5641   401000.0          392840.0   313200
# 5658   305500.0          302894.0   304000
# 5675   389600.0          391867.0   405000
# 5686   336100.0          329797.0   335000
# 5695   320100.0          328567.0   320000
# 5745   400000.0          362433.0   380000
# 6515   862100.0          863980.0   800000
# 6529   872500.0               0.0   865000
# 7709   642600.0          656432.0   640000
# 8753   688800.0          681629.0   683000
# 8949   698700.0          953026.0   697000
#
# [46 rows x 39 columns]

# %%
predictors = ['schools/1/rating',
'mortgageRates/thirtyYearFixedRate',
'nearbyHomes/1/price',
'bathrooms',
'homeType',
'state',
'adTargets/sqft',
'zipcode',
'bedrooms',
'price'
]

# %%
corr_matrix = df[predictors].corr(numeric_only = True)

price_corr = corr_matrix[['price']].sort_values(by=['price'],ascending=False).drop('price')
# Plot the heatmap
plt.figure(figsize=(10, 12))
sns.heatmap(price_corr, annot = False)
plt.title('Correlation between Predictors and Price')
plt.show()
#looking at coorelation in order to remove variables, as the first polynomial regression was way overfit

# %%
#bedrooms, photocount, yearbuilt, schools/0/distance, propertytaxrate, zipcode

# %%
new_df = df[predictors].dropna().reset_index()
new_df.shape
# Out:
# (1598, 9)

# %%
new_df = new_df.drop(columns = 'index')

# %%
new_df['state'].value_counts()
# Out:
# state
# CA    1598
# Name: count, dtype: int64

# %%
new_df.describe
# Out:
# <bound method NDFrame.describe of       schools/1/rating  mortgageRates/thirtyYearFixedRate  \
# 0                  9.0                              6.194
# 1                  9.0                              6.194
# 2                  8.0                              6.194
# 3                  9.0                              6.194
# 4                  7.0                              6.194
# ...                ...                                ...
# 1593               7.0                              5.879
# 1594               7.0                              5.527
# 1595               4.0                              5.879
# 1596               4.0                              5.527
# 1597               3.0                              5.879
#
#       nearbyHomes/1/price  bathrooms       homeType state  adTargets/sqft  \
# 0               2700000.0        2.0          CONDO    CA          1493.0
# 1               1870600.0        3.0  SINGLE_FAMILY    CA          2163.0
# 2               2295500.0        3.0  SINGLE_FAMILY    CA          3472.0
# 3               1250000.0        2.0          CONDO    CA          1975.0
# 4               1565100.0        4.0  SINGLE_FAMILY    CA          4283.0
# ...                   ...        ...            ...   ...             ...
# 1593             650000.0        2.0      TOWNHOUSE    CA          1182.0
# 1594             708900.0        3.0  SINGLE_FAMILY    CA          2528.0
# 1595             719900.0        4.0  SINGLE_FAMILY    CA          2605.0
# 1596             528700.0        3.0  SINGLE_FAMILY    CA          2272.0
# 1597                  0.0        8.0   MULTI_FAMILY    CA          4651.0
#
#         price
# 0     1600000
# 1     2050000
# 2     2340000
# 3     1625000
# 4     1642000
# ...       ...
# 1593   635000
# 1594   515000
# 1595   692900
# 1596   505000
# 1597   725000
#
# [1598 rows x 8 columns]>

# %%
new_df.head()
# Out:
#    schools/1/rating  mortgageRates/thirtyYearFixedRate  nearbyHomes/1/price  \
# 0               9.0                              6.194            2700000.0
# 1               9.0                              6.194            1870600.0
# 2               8.0                              6.194            2295500.0
# 3               9.0                              6.194            1250000.0
# 4               7.0                              6.194            1565100.0
#
#    bathrooms       homeType state  adTargets/sqft    price
# 0        2.0          CONDO    CA          1493.0  1600000
# 1        3.0  SINGLE_FAMILY    CA          2163.0  2050000
# 2        3.0  SINGLE_FAMILY    CA          3472.0  2340000
# 3        2.0          CONDO    CA          1975.0  1625000
# 4        4.0  SINGLE_FAMILY    CA          4283.0  1642000

# %%
#new_df = pd.get_dummies(new_df)

# %%
new_df.shape
# Out:
# (1598, 8)

# %%
unique_df = new_df.drop_duplicates()
unique_df.shape
# Out:
# (1589, 8)

# %%
new_df.head()
# Out:
#    schools/1/rating  mortgageRates/thirtyYearFixedRate  nearbyHomes/1/price  \
# 0               9.0                              6.194            2700000.0
# 1               9.0                              6.194            1870600.0
# 2               8.0                              6.194            2295500.0
# 3               9.0                              6.194            1250000.0
# 4               7.0                              6.194            1565100.0
#
#    bathrooms       homeType state  adTargets/sqft    price
# 0        2.0          CONDO    CA          1493.0  1600000
# 1        3.0  SINGLE_FAMILY    CA          2163.0  2050000
# 2        3.0  SINGLE_FAMILY    CA          3472.0  2340000
# 3        2.0          CONDO    CA          1975.0  1625000
# 4        4.0  SINGLE_FAMILY    CA          4283.0  1642000

# %%
# modeling imports
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV # Linear Regression Model
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, SplineTransformer, OneHotEncoder #Z-score variables, Polynomial
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error #model evaluation
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
# pipeline imports
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import make_column_transformer

# %%
predictors = new_df.columns.tolist()
contin = new_df.columns.tolist()
len(predictors)
# Out:
# 8

# %%
predictors.remove('price')
contin.remove('state')
contin.remove('homeType')
contin.remove('price')
cat = ['state', 'homeType']

# %%
len(predictors)
# Out:
# 7

# %%
len(contin)
# Out:
# 5

# %%
X = new_df[predictors]
y = new_df["price"]


X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 101)
# z score
z = make_column_transformer((StandardScaler(), contin),
                            (OneHotEncoder(handle_unknown='ignore'), cat),
                            remainder = "passthrough")

lr = LinearRegression()

pipe = Pipeline([("zscore", z),
                #("poly", PolynomialFeatures(degree = 3)), #any number of polynomials added made the R2 unreasonable, but the model is still not sufficient
                ("linearregression", lr)])

# %%
duplicated_columns = new_df.columns[new_df.columns.duplicated()]
print(duplicated_columns)
# Out:
# Index([], dtype='object')

# %%
# fit
pipe.fit(X_train,y_train)


# predict
y_pred_train = pipe.predict(X_train)
y_pred_test = pipe.predict(X_test)

# assess
print("Train MSE : ", mean_squared_error(y_train,y_pred_train))
print("Train MAE : ", mean_absolute_error(y_train,y_pred_train))
print("Train MAPE: ", mean_squared_error(y_train,y_pred_train))
print("Train R2  : ", r2_score(y_train,y_pred_train))

print("Test MSE  : ", mean_squared_error(y_test,y_pred_test))
print("Test MAE  : ", mean_absolute_error(y_test,y_pred_test))
print("Test MAPE : ", mean_squared_error(y_test,y_pred_test))
print("Test R2  : ", r2_score(y_test,y_pred_test))
#R2 is way too high
# Out:
# Train MSE :  46069049638.5114
# Train MAE :  140294.1419483024
# Train MAPE:  46069049638.5114
# Train R2  :  0.8843584277365936
# Test MSE  :  29783155898.4954
# Test MAE  :  119480.39624713696
# Test MAPE :  29783155898.4954
# Test R2  :  0.9153646872739596

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error #model evaluation
from sklearn.model_selection import train_test_split, KFold, LeaveOneOut

# %%
# validation
kf = KFold(11)

mse = {"train": [], "test": []}
mae = {"train": [], "test": []}
r2 = {"train": [], "test": []}


for train, test in kf.split(X):
    X_train = X.iloc[train]
    X_test  = X.iloc[test]
    y_train = y[train]
    y_test  = y[test]

    # fit
    pipe.fit(X_train,y_train)

    # predict
    y_pred_train = pipe.predict(X_train)
    y_pred_test = pipe.predict(X_test)

    # assess
    mse["train"].append(mean_squared_error(y_train,y_pred_train))
    mse["test"].append(mean_squared_error(y_test,y_pred_test))
    

    mae["train"].append(mean_absolute_error(y_train,y_pred_train))
    mae["test"].append(mean_absolute_error(y_test,y_pred_test))
    
    r2["train"].append(r2_score(y_train,y_pred_train))
    r2["test"].append(r2_score(y_test,y_pred_test))

print("Train MSEs:", mse["train"])
print("Test MSEs :", mse["test"])
print("Train MSE :", np.mean(mse["train"]))
print("Test MSE  :", np.mean(mse["test"]))

print("Train R2s:", r2["train"])
print("Test R2s :", r2["test"])
print("Train R2 :", np.mean(r2["train"]))
print("Test R2  :", np.mean(r2["test"]))

#kfolds reduces variance and increases bias, essentially reducing th complexity
# Out:
# Train MSEs: [36717044637.48245, 38139895996.06431, 43374423317.812546, 39820370509.36018, 44593254996.49902, 45199949554.69843, 46041275656.45033, 44915958704.21652, 42111787218.79993, 42995260327.2073, 41473212678.90663]
# Test MSEs : [107553569783.02875, 92130297199.1423, 36238490091.26143, 75250981510.26419, 23475273816.58096, 17401190905.984966, 8783072754.171928, 20287712347.851063, 53305132784.323364, 47977909642.61265, 69809299186.93282]
# Train MSE : 42307493963.408875
# Test MSE  : 50201175456.559494
# Train R2s: [0.8895957931974414, 0.8875137131200558, 0.8811843356444465, 0.8898121417514171, 0.8885397961562771, 0.8862220907724021, 0.8853539801143911, 0.8871752749594441, 0.8971407087324922, 0.8986454936151458, 0.9014548892814]
# Test R2s : [0.239750105843484, 0.4349857316451875, 0.6943672461682391, 0.8589673003048188, -2.8208953167044655, -2.281577340867519, -0.8011404167377778, -3.0942307220288647, -0.24262663234909754, -0.5143115923185975, -7.973856245048326]
# Train R2 : 0.8902398379404467
# Test R2  : -1.40914253473572

# %% [markdown]
# trying tree models now

# %%
# models
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor # Decision Tree
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor # random forest
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor # gradient boosting
import xgboost as xg
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %%
new_df['state'] = new_df["state"].astype("category")
new_df['homeType'] = new_df["homeType"].astype("category")
new_df['zipcode'] = new_df['zipcode'].astype("category")

# %%
predictors
# Out:
# ['schools/1/rating',
#  'mortgageRates/thirtyYearFixedRate',
#  'nearbyHomes/1/price',
#  'bathrooms',
#  'homeType',
#  'state',
#  'adTargets/sqft']

# %%
new_df.dtypes
# Out:
# schools/1/rating                      float64
# mortgageRates/thirtyYearFixedRate     float64
# nearbyHomes/1/price                   float64
# bathrooms                             float64
# homeType                             category
# state                                category
# adTargets/sqft                        float64
# price                                   int64
# dtype: object

# %%
X = new_df[predictors]
y = new_df["price"]


X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 101)

# %%
xgb = xg.XGBRegressor(n_estimators = 1000, max_depth = 3, random_state = 101, booster = 'gbtree', learning_rate = 0.01, enable_categorical=True)

xgb.fit(X_train, y_train)
xgb_predictions = xgb.predict(X_test)
mean_squared_error(y_test, xgb_predictions)
# Out:
# 17086142845.40066

# %% [markdown]
# performing cross validation

# %%
# model validation
xgb = xg.XGBRegressor(n_estimators = 1000, max_depth = 3, random_state = 101, booster = 'gbtree', learning_rate = 0.01, enable_categorical=True)
kf = KFold(n_splits = 11)
results = cross_val_score(xgb, X, y, cv=kf)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))

mse = {"train": [], "test": []}
mae = {"train": [], "test": []}
mape = {"train": [], "test": []}
r2 = {"train": [], "test": []}

for train, test in kf.split(X):
    X_train = X.iloc[train]
    X_test  = X.iloc[test]
    y_train = y[train]
    y_test  = y[test]

    # fit
    xgb.fit(X_train,y_train)

    # predict
    y_pred_train = xgb.predict(X_train)
    y_pred_test = xgb.predict(X_test)

    # assess
    mse["train"].append(mean_squared_error(y_train,y_pred_train))
    mse["test"].append(mean_squared_error(y_test,y_pred_test))
    
    mae["train"].append(mean_absolute_error(y_train,y_pred_train))
    mae["test"].append(mean_absolute_error(y_test,y_pred_test))

    mape["train"].append(mean_absolute_percentage_error(y_train,y_pred_train))
    mape["test"].append(mean_absolute_percentage_error(y_test,y_pred_test))

    r2["train"].append(r2_score(y_train,y_pred_train))
    r2["test"].append(r2_score(y_test,y_pred_test))

#print("Train MSEs:", mse["train"])
#print("Test MSEs :", mse["test"])
print("Train MSE :", np.mean(mse["train"]))
print("Test MSE  :", np.mean(mse["test"]))

#print("Train MAEs:", mae["train"])
#print("Test MAEs :", mae["test"])
print("Train MAE :", np.mean(mae["train"]))
print("Test MAE  :", np.mean(mae["test"]))

#print("Train MAPEs:", mape["train"])
#print("Test MAPEs :", mape["test"])
print("Train MAPE :", np.mean(mape["train"]))
print("Test MAPE  :", np.mean(mape["test"]))

#print("Train R2s:", r2["train"])
#print("Test R2s :", r2["test"])
print("Train R2 :", np.mean(r2["train"]))
print("Test R2  :", np.mean(r2["test"]))
# Out:
# Accuracy: 42.23% (59.26%)
# Train MSE : 13449919078.739147
# Test MSE  : 24555971414.429337
# Train MAE : 75659.75471302414
# Test MAE  : 99482.15804298
# Train MAPE : 0.09277830492715938
# Test MAPE  : 0.11750402980069063
# Train R2 : 0.9652499556541443
# Test R2  : 0.4222834218632091

# %% [markdown]
# early stopping on n_estimators

# %%
xgb = xg.XGBRegressor(n_estimators = 1000, max_depth = 3, random_state = 101, booster = 'gbtree', learning_rate = 0.01, enable_categorical=True, eval_metric = "rmse", early_stopping_rounds=50,)
xgb.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=True
)

# Make predictions and evaluate
y_pred = xgb.predict(X_test)
val_error = mean_squared_error(y_test, y_pred)
print(f"Validation error: {val_error}")
# Out:
# [0]	validation_0-rmse:279120.98410
# [1]	validation_0-rmse:276777.00385
# [2]	validation_0-rmse:274464.35370
# [3]	validation_0-rmse:272182.78571
# [4]	validation_0-rmse:269931.99787
# [5]	validation_0-rmse:267711.74558
# [6]	validation_0-rmse:265521.75544
# [7]	validation_0-rmse:263336.01543
# [8]	validation_0-rmse:261234.95954
# [9]	validation_0-rmse:259107.18455
# [10]	validation_0-rmse:257061.96839
# [11]	validation_0-rmse:254991.16376
# [12]	validation_0-rmse:253000.83422
# [13]	validation_0-rmse:250957.83986
# [14]	validation_0-rmse:249049.21078
# [15]	validation_0-rmse:247062.00319
# [16]	validation_0-rmse:245205.41635
# [17]	validation_0-rmse:243272.98871
# [18]	validation_0-rmse:241467.47738
# [19]	validation_0-rmse:239588.83974
# [20]	validation_0-rmse:237833.45988
# [21]	validation_0-rmse:235948.07518
# [22]	validation_0-rmse:234218.35532
# [23]	validation_0-rmse:232387.30981
# [24]	validation_0-rmse:230702.51185
# [25]	validation_0-rmse:228990.90117
# [26]	validation_0-rmse:227294.45451
# [27]	validation_0-rmse:225632.96690
# [28]	validation_0-rmse:224009.83413
# [29]	validation_0-rmse:222410.56618
# [30]	validation_0-rmse:220760.17713
# [31]	validation_0-rmse:219271.23492
# [32]	validation_0-rmse:217670.51289
# [33]	validation_0-rmse:216166.30433
# [34]	validation_0-rmse:214665.98935
# [35]	validation_0-rmse:213168.05399
# [36]	validation_0-rmse:211599.86573
# [37]	validation_0-rmse:210173.63331
# [38]	validation_0-rmse:208709.61581
# [39]	validation_0-rmse:207326.72597
# [40]	validation_0-rmse:205925.71568
# [41]	validation_0-rmse:204509.69406
# [42]	validation_0-rmse:203233.65325
# [43]	validation_0-rmse:201879.64402
# [44]	validation_0-rmse:200655.19781
# [45]	validation_0-rmse:199280.54059
# [46]	validation_0-rmse:198131.05819
# [47]	validation_0-rmse:196869.89587
# [48]	validation_0-rmse:195725.15942
# [49]	validation_0-rmse:194493.42273
# [50]	validation_0-rmse:193376.34663
# [51]	validation_0-rmse:192136.53076
# [284]	validation_0-rmse:130082.51046
# [285]	validation_0-rmse:130056.43055
# [286]	validation_0-rmse:130026.75436
# [287]	validation_0-rmse:129997.97870
# [288]	validation_0-rmse:129993.39968
# [289]	validation_0-rmse:129965.81348
# [290]	validation_0-rmse:130041.55939
# [291]	validation_0-rmse:130024.59391
# [292]	validation_0-rmse:130020.87627
# [293]	validation_0-rmse:129995.97099
# [294]	validation_0-rmse:129971.10655
# [295]	validation_0-rmse:129947.39780
# [296]	validation_0-rmse:129924.45312
# [297]	validation_0-rmse:129911.49856
# Validation error: 16523500509.741602

# %%
xgb = xg.XGBRegressor(n_estimators = 757, max_depth = 3, random_state = 101, booster = 'gbtree', learning_rate = 0.01, enable_categorical=True)

# model validation
kf = KFold(n_splits = 11)
results = cross_val_score(xgb, X, y, cv=kf)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))

mse = {"train": [], "test": []}
mae = {"train": [], "test": []}
mape = {"train": [], "test": []}
r2 = {"train": [], "test": []}

for train, test in kf.split(X):
    X_train = X.iloc[train]
    X_test  = X.iloc[test]
    y_train = y[train]
    y_test  = y[test]

    # fit
    xgb.fit(X_train,y_train)

    # predict
    y_pred_train = xgb.predict(X_train)
    y_pred_test = xgb.predict(X_test)

    # assess
    mse["train"].append(mean_squared_error(y_train,y_pred_train))
    mse["test"].append(mean_squared_error(y_test,y_pred_test))
    
    mae["train"].append(mean_absolute_error(y_train,y_pred_train))
    mae["test"].append(mean_absolute_error(y_test,y_pred_test))

    mape["train"].append(mean_absolute_percentage_error(y_train,y_pred_train))
    mape["test"].append(mean_absolute_percentage_error(y_test,y_pred_test))

    r2["train"].append(r2_score(y_train,y_pred_train))
    r2["test"].append(r2_score(y_test,y_pred_test))

print("Train MSEs:", mse["train"])
print("Test MSEs :", mse["test"])
print("Train MSE :", np.mean(mse["train"]))
print("Test MSE  :", np.mean(mse["test"]))

print("Train MAEs:", mae["train"])
print("Test MAEs :", mae["test"])
print("Train MAE :", np.mean(mae["train"]))
print("Test MAE  :", np.mean(mae["test"]))

print("Train MAPEs:", mape["train"])
print("Test MAPEs :", mape["test"])
print("Train MAPE :", np.mean(mape["train"]))
print("Test MAPE  :", np.mean(mape["test"]))

print("Train R2s:", r2["train"])
print("Test R2s :", r2["test"])
print("Train R2 :", np.mean(r2["train"]))
print("Test R2  :", np.mean(r2["test"]))
# Out:
# Accuracy: 42.27% (57.43%)
# Train MSEs: [11491918352.420252, 11250325960.3335, 14075691569.958801, 12403782867.945528, 15941365253.068014, 15999736749.173517, 15940647403.221605, 16018846580.990545, 15561394141.493942, 14355292529.29793, 14933251809.803396]
# Test MSEs : [66290387020.89124, 62315185931.575, 28145660155.074165, 58395378042.19736, 3938603656.983526, 2308890422.8323293, 2929680230.102142, 1516738273.3813055, 6419540139.263098, 23041131443.311672, 17830248133.807724]
# Train MSE : 14361113928.882458
# Test MSE  : 24830131222.674503
# Train MAEs: [68702.70235020661, 68901.69021177686, 75330.15096633953, 73250.22235246042, 82736.71773916036, 83194.0696511528, 82894.12460211631, 83831.31537121473, 81575.77890571232, 75847.23597728836, 78755.96774991397]
# Test MAEs : [189708.03467465754, 193323.51755136985, 140318.1455479452, 153727.1426724138, 47272.0625, 35394.96842672414, 37138.55517241379, 29384.019504310345, 45031.18308189655, 115415.26918103448, 111689.8036637931]
# Train MAE : 77729.08871612203
# Test MAE  : 99854.79108877806
# Train MAPEs: [0.0940912228288988, 0.09401880087524656, 0.09825280316428624, 0.09312694892488003, 0.09457344632660353, 0.09611541051263425, 0.09592253892191553, 0.09826897308795365, 0.09667055236010237, 0.09239096626711173, 0.0936615184965947]
# Test MAPEs : [0.11135281133608246, 0.11157069584128823, 0.09297036607882858, 0.12092616398519151, 0.1459339769728236, 0.10955672529762506, 0.10716406274721, 0.09229091444639945, 0.0861744991425185, 0.1453622726152963, 0.17950779512338969]
# Train MAPE : 0.09519028925147523
# Test MAPE  : 0.11843729850787757
# Train R2s: [0.9654450416564941, 0.9668193459510803, 0.9614424109458923, 0.9656772017478943, 0.9601547718048096, 0.9597252607345581, 0.9603066444396973, 0.9597621560096741, 0.9619908332824707, 0.9661597013473511, 0.9645168781280518]
# Test R2s : [0.5314217805862427, 0.6178350448608398, 0.7626215815544128, 0.8905574679374695, 0.35894280672073364, 0.5645813941955566, 0.39921194314956665, 0.6939094662666321, 0.8503503799438477, 0.2727600932121277, -1.2920451164245605]
# Train R2 : 0.9629091132770885
# Test R2  : 0.4227406220002608

# %%
from xgboost import plot_importance
plt.figure(figsize=(18,12))
plot_importance(xgb)
plt.show()

# %%
import shap
# Calculate SHAP values
explainer = shap.TreeExplainer(xgb)
shap_values = explainer.shap_values(X_test)

# Summarize the effects of all the features
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %%
predictors = ['schools/1/rating',
'mortgageRates/thirtyYearFixedRate',
'nearbyHomes/1/price',
'bathrooms',
'bedrooms',
'homeType',
'adTargets/sqft',
]

# %%
final_df = new_df.drop(columns= ['resoFacts/bathroomsFull', 'resoFacts/bathrooms', 'state'])
final_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15316\1774088599.py in <module>
# ----> 1 final_df = new_df.drop(columns= ['resoFacts/bathroomsFull', 'resoFacts/bathrooms', 'state'])
#       2 final_df.head()
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['resoFacts/bathroomsFull', 'resoFacts/bathrooms'] not found in axis"

# %%
X = final_df[predictors]
y = final_df["price"]


X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 101)

# %%
xgb = xg.XGBRegressor(n_estimators = 753, max_depth = 3, random_state = 101, booster = 'gbtree', 
                      learning_rate = 0.01, enable_categorical=True, min_child_weight = 8,
                     gamma=1, subsample=0.8, colsample_bytree=0.8, reg_alpha=0.1, reg_lambda=1.0,)

# model validation
kf = KFold(n_splits = 7)
results = cross_val_score(xgb, X, y, cv=kf)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))

mse = {"train": [], "test": []}
mae = {"train": [], "test": []}
mape = {"train": [], "test": []}
r2 = {"train": [], "test": []}

for train, test in kf.split(X):
    X_train = X.iloc[train]
    X_test  = X.iloc[test]
    y_train = y[train]
    y_test  = y[test]

    # fit
    xgb.fit(X_train,y_train)

    # predict
    y_pred_train = xgb.predict(X_train)
    y_pred_test = xgb.predict(X_test)

    # assess
    mse["train"].append(mean_squared_error(y_train,y_pred_train))
    mse["test"].append(mean_squared_error(y_test,y_pred_test))
    
    mae["train"].append(mean_absolute_error(y_train,y_pred_train))
    mae["test"].append(mean_absolute_error(y_test,y_pred_test))

    mape["train"].append(mean_absolute_percentage_error(y_train,y_pred_train))
    mape["test"].append(mean_absolute_percentage_error(y_test,y_pred_test))

    r2["train"].append(r2_score(y_train,y_pred_train))
    r2["test"].append(r2_score(y_test,y_pred_test))

#print("Train MSEs:", mse["train"])
#print("Test MSEs :", mse["test"])
print("Train MSE :", np.mean(mse["train"]))
print("Test MSE  :", np.mean(mse["test"]))

#print("Train MAEs:", mae["train"])
#print("Test MAEs :", mae["test"])
print("Train MAE :", np.mean(mae["train"]))
print("Test MAE  :", np.mean(mae["test"]))

#print("Train MAPEs:", mape["train"])
#print("Test MAPEs :", mape["test"])
print("Train MAPE :", np.mean(mape["train"]))
print("Test MAPE  :", np.mean(mape["test"]))

#print("Train R2s:", r2["train"])
#print("Test R2s :", r2["test"])
print("Train R2 :", np.mean(r2["train"]))
print("Test R2  :", np.mean(r2["test"]))

# %%
plt.figure(figsize=(18,12))
plot_importance(xgb)
plt.show()

# %%
# Calculate SHAP values
explainer = shap.TreeExplainer(xgb)
shap_values = explainer.shap_values(X_test)

# Summarize the effects of all the features
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %%
variables = ['schools/1/rating',
'mortgageRates/thirtyYearFixedRate',
'nearbyHomes/1/price',
'bathrooms',
'bedrooms',
'homeType',
'adTargets/sqft',
             'price'
]

# %%
corr_matrix = final_df[variables].corr(numeric_only = True)

price_corr = corr_matrix[['price']].sort_values(by=['price'],ascending=False).drop('price')
# Plot the heatmap
plt.figure(figsize=(10, 12))
sns.heatmap(price_corr, annot = False)
plt.title('Correlation between Predictors and Price')
plt.show()

# %%
final_df.shape
